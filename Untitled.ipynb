# %%
import pandas as pd

from matplotlib.pyplot import plot

# %%
stock_market=pd.read_csv('./symbols_valid_meta.csv')

# %%
stock_market
# Out:
#      Nasdaq Traded Symbol                                      Security Name  \
# 0                Y      A            Agilent Technologies, Inc. Common Stock
# 1                Y     AA                    Alcoa Corporation Common Stock
# 2                Y   AAAU                       Perth Mint Physical Gold ETF
# 3                Y   AACG  ATA Creativity Global - American Depositary Sh...
# 4                Y   AADR                AdvisorShares Dorsey Wright ADR ETF
# ...            ...    ...                                                ...
# 8044             Y    ZUO                   Zuora, Inc. Class A Common Stock
# 8045             Y    ZVO                          Zovio Inc. - Common Stock
# 8046             Y   ZYME                       Zymeworks Inc. Common Shares
# 8047             Y   ZYNE       Zynerba Pharmaceuticals, Inc. - Common Stock
# 8048             Y   ZYXI                         Zynex, Inc. - Common Stock
#
# ...

# %%
stock_market.describe(include='all')
# Out:
#        Nasdaq Traded Symbol                                Security Name  \
# count           8049   8049                                         8049
# unique             1   8049                                         8045
# top                Y      A  Urstadt Biddle Properties Inc. Common Stock
# freq            8049      1                                            2
# mean             NaN    NaN                                          NaN
# std              NaN    NaN                                          NaN
# min              NaN    NaN                                          NaN
# 25%              NaN    NaN                                          NaN
# 50%              NaN    NaN                                          NaN
# 75%              NaN    NaN                                          NaN
# max              NaN    NaN                                          NaN
#
#        Listing Exchange Market Category   ETF  Round Lot Size Test Issue  \
# ...

# %%
stock_market['Market Category'].isnull()==True
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8044    False
# 8045    False
# 8046    False
# 8047    False
# 8048    False
# Name: Market Category, Length: 8049, dtype: bool
